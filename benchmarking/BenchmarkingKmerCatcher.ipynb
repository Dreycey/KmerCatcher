# %%
import subprocess
import time
import matplotlib.pyplot as plt

# %% [markdown]
# ## Functions for benchmarking

# %%
def run_kmerfinder(file_1, file_2, kmer_size, hashtable_size, use_rolling=False):
    """
    Description:
        This function runs KmerCatcher based on input
    Args:
        1.
        2.
        3.
    """
    args = ["./KmerFinder", f"{file_1}", f"{file_2}", f"{kmer_size}", f"{hashtable_size}"]
    if use_rolling:
        args += ["--use_rolling"]
    print(args)
    subprocess.run(args)

# %% [markdown]
# ## Testing impact of kmer size

# %%
file_1 = "test_files/bacterial_genome_1.txt"
file_2 = "test_files/bacterial_genome_2.txt"
hashtable_size = 50000000
benchmarking = {}
for use_rolling in [1,0]:
    for kmer_size in range(10,500,10):
        start = time.time()
        run_kmerfinder(file_1, file_2, kmer_size, hashtable_size, use_rolling)
        time_to_run = time.time() - start
        benchmarking[f"{use_rolling},{hashtable_size},{kmer_size}"] = time_to_run
        print(f"for k={kmer_size} it took {time_to_run}")
# Out:
# ['./KmerFinder', 'test_files/bacterial_genome_1.txt', 'test_files/bacterial_genome_2.txt', '10', '50000000', '--use_rolling']
# for k=10 it took 38.18814492225647
# ['./KmerFinder', 'test_files/bacterial_genome_1.txt', 'test_files/bacterial_genome_2.txt', '20', '50000000', '--use_rolling']
# for k=20 it took 22.468089818954468
# ['./KmerFinder', 'test_files/bacterial_genome_1.txt', 'test_files/bacterial_genome_2.txt', '30', '50000000', '--use_rolling']
# for k=30 it took 22.610645055770874
# ['./KmerFinder', 'test_files/bacterial_genome_1.txt', 'test_files/bacterial_genome_2.txt', '40', '50000000', '--use_rolling']
# for k=40 it took 22.52168297767639
# ['./KmerFinder', 'test_files/bacterial_genome_1.txt', 'test_files/bacterial_genome_2.txt', '50', '50000000', '--use_rolling']
# for k=50 it took 22.594316959381104
# ['./KmerFinder', 'test_files/bacterial_genome_1.txt', 'test_files/bacterial_genome_2.txt', '60', '50000000', '--use_rolling']
# for k=60 it took 22.51002073287964
# ['./KmerFinder', 'test_files/bacterial_genome_1.txt', 'test_files/bacterial_genome_2.txt', '70', '50000000', '--use_rolling']
# for k=70 it took 22.926429986953735
# ['./KmerFinder', 'test_files/bacterial_genome_1.txt', 'test_files/bacterial_genome_2.txt', '80', '50000000', '--use_rolling']
# for k=80 it took 22.918914079666138
# ['./KmerFinder', 'test_files/bacterial_genome_1.txt', 'test_files/bacterial_genome_2.txt', '90', '50000000', '--use_rolling']
# for k=90 it took 22.952291011810303
# ['./KmerFinder', 'test_files/bacterial_genome_1.txt', 'test_files/bacterial_genome_2.txt', '100', '50000000', '--use_rolling']
# for k=100 it took 23.04552125930786
# ['./KmerFinder', 'test_files/bacterial_genome_1.txt', 'test_files/bacterial_genome_2.txt', '110', '50000000', '--use_rolling']
# for k=110 it took 23.363796949386597
# ['./KmerFinder', 'test_files/bacterial_genome_1.txt', 'test_files/bacterial_genome_2.txt', '120', '50000000', '--use_rolling']
# for k=120 it took 23.232370853424072
# ['./KmerFinder', 'test_files/bacterial_genome_1.txt', 'test_files/bacterial_genome_2.txt', '130', '50000000', '--use_rolling']
# for k=130 it took 23.363874912261963
# ['./KmerFinder', 'test_files/bacterial_genome_1.txt', 'test_files/bacterial_genome_2.txt', '140', '50000000', '--use_rolling']
# for k=140 it took 23.19517970085144
# ['./KmerFinder', 'test_files/bacterial_genome_1.txt', 'test_files/bacterial_genome_2.txt', '150', '50000000', '--use_rolling']
# for k=150 it took 23.296924114227295
# ['./KmerFinder', 'test_files/bacterial_genome_1.txt', 'test_files/bacterial_genome_2.txt', '160', '50000000', '--use_rolling']
# for k=160 it took 23.13777732849121
# ['./KmerFinder', 'test_files/bacterial_genome_1.txt', 'test_files/bacterial_genome_2.txt', '170', '50000000', '--use_rolling']
# for k=170 it took 23.225473165512085
# ['./KmerFinder', 'test_files/bacterial_genome_1.txt', 'test_files/bacterial_genome_2.txt', '180', '50000000', '--use_rolling']
# for k=180 it took 23.25283408164978
# ['./KmerFinder', 'test_files/bacterial_genome_1.txt', 'test_files/bacterial_genome_2.txt', '190', '50000000', '--use_rolling']
# for k=190 it took 23.39423680305481
# ['./KmerFinder', 'test_files/bacterial_genome_1.txt', 'test_files/bacterial_genome_2.txt', '200', '50000000', '--use_rolling']
# for k=200 it took 23.77723526954651
# ['./KmerFinder', 'test_files/bacterial_genome_1.txt', 'test_files/bacterial_genome_2.txt', '210', '50000000', '--use_rolling']
# for k=210 it took 23.69278883934021
# ['./KmerFinder', 'test_files/bacterial_genome_1.txt', 'test_files/bacterial_genome_2.txt', '220', '50000000', '--use_rolling']
# for k=220 it took 23.843711137771606
# ['./KmerFinder', 'test_files/bacterial_genome_1.txt', 'test_files/bacterial_genome_2.txt', '230', '50000000', '--use_rolling']
# for k=230 it took 23.9846088886261
# ['./KmerFinder', 'test_files/bacterial_genome_1.txt', 'test_files/bacterial_genome_2.txt', '240', '50000000', '--use_rolling']
# for k=240 it took 24.564457893371582
# ['./KmerFinder', 'test_files/bacterial_genome_1.txt', 'test_files/bacterial_genome_2.txt', '250', '50000000', '--use_rolling']
# for k=250 it took 24.693954944610596
# ['./KmerFinder', 'test_files/bacterial_genome_1.txt', 'test_files/bacterial_genome_2.txt', '260', '50000000', '--use_rolling']
# for k=260 it took 24.454617738723755
# ['./KmerFinder', 'test_files/bacterial_genome_1.txt', 'test_files/bacterial_genome_2.txt', '270', '50000000', '--use_rolling']
# for k=270 it took 25.59987211227417
# ['./KmerFinder', 'test_files/bacterial_genome_1.txt', 'test_files/bacterial_genome_2.txt', '280', '50000000', '--use_rolling']
# for k=280 it took 24.57853603363037
# ['./KmerFinder', 'test_files/bacterial_genome_1.txt', 'test_files/bacterial_genome_2.txt', '290', '50000000', '--use_rolling']
# for k=290 it took 24.886198043823242
# ['./KmerFinder', 'test_files/bacterial_genome_1.txt', 'test_files/bacterial_genome_2.txt', '300', '50000000', '--use_rolling']
# for k=300 it took 24.970409154891968
# ['./KmerFinder', 'test_files/bacterial_genome_1.txt', 'test_files/bacterial_genome_2.txt', '310', '50000000', '--use_rolling']
# for k=310 it took 25.179528951644897
# ['./KmerFinder', 'test_files/bacterial_genome_1.txt', 'test_files/bacterial_genome_2.txt', '320', '50000000', '--use_rolling']
# for k=320 it took 25.013370990753174
# ['./KmerFinder', 'test_files/bacterial_genome_1.txt', 'test_files/bacterial_genome_2.txt', '330', '50000000', '--use_rolling']
# for k=330 it took 24.940269947052002
# ['./KmerFinder', 'test_files/bacterial_genome_1.txt', 'test_files/bacterial_genome_2.txt', '340', '50000000', '--use_rolling']
# for k=340 it took 25.091545820236206
# ['./KmerFinder', 'test_files/bacterial_genome_1.txt', 'test_files/bacterial_genome_2.txt', '350', '50000000', '--use_rolling']
# for k=350 it took 25.159362077713013
# ['./KmerFinder', 'test_files/bacterial_genome_1.txt', 'test_files/bacterial_genome_2.txt', '360', '50000000', '--use_rolling']
# for k=360 it took 25.54804515838623
# ['./KmerFinder', 'test_files/bacterial_genome_1.txt', 'test_files/bacterial_genome_2.txt', '370', '50000000', '--use_rolling']
# for k=370 it took 25.58424425125122
# ['./KmerFinder', 'test_files/bacterial_genome_1.txt', 'test_files/bacterial_genome_2.txt', '380', '50000000', '--use_rolling']
# for k=380 it took 25.36019206047058
# ['./KmerFinder', 'test_files/bacterial_genome_1.txt', 'test_files/bacterial_genome_2.txt', '390', '50000000', '--use_rolling']
# for k=390 it took 25.639249801635742
# ['./KmerFinder', 'test_files/bacterial_genome_1.txt', 'test_files/bacterial_genome_2.txt', '400', '50000000', '--use_rolling']
# for k=400 it took 25.391963243484497
# ['./KmerFinder', 'test_files/bacterial_genome_1.txt', 'test_files/bacterial_genome_2.txt', '410', '50000000', '--use_rolling']
# for k=410 it took 25.383650064468384
# ['./KmerFinder', 'test_files/bacterial_genome_1.txt', 'test_files/bacterial_genome_2.txt', '420', '50000000', '--use_rolling']
# for k=420 it took 25.736073970794678
# ['./KmerFinder', 'test_files/bacterial_genome_1.txt', 'test_files/bacterial_genome_2.txt', '430', '50000000', '--use_rolling']
# for k=430 it took 25.920011043548584
# ['./KmerFinder', 'test_files/bacterial_genome_1.txt', 'test_files/bacterial_genome_2.txt', '440', '50000000', '--use_rolling']
# for k=440 it took 26.443278074264526
# ['./KmerFinder', 'test_files/bacterial_genome_1.txt', 'test_files/bacterial_genome_2.txt', '450', '50000000', '--use_rolling']
# for k=450 it took 25.85365390777588
# ['./KmerFinder', 'test_files/bacterial_genome_1.txt', 'test_files/bacterial_genome_2.txt', '460', '50000000', '--use_rolling']
# for k=460 it took 26.80615782737732
# ['./KmerFinder', 'test_files/bacterial_genome_1.txt', 'test_files/bacterial_genome_2.txt', '470', '50000000', '--use_rolling']
# for k=470 it took 25.814828157424927
# ['./KmerFinder', 'test_files/bacterial_genome_1.txt', 'test_files/bacterial_genome_2.txt', '480', '50000000', '--use_rolling']
# for k=480 it took 25.908574104309082
# ['./KmerFinder', 'test_files/bacterial_genome_1.txt', 'test_files/bacterial_genome_2.txt', '490', '50000000', '--use_rolling']
# for k=490 it took 26.14021396636963
# ['./KmerFinder', 'test_files/bacterial_genome_1.txt', 'test_files/bacterial_genome_2.txt', '10', '50000000']
# for k=10 it took 49.007883071899414
# ['./KmerFinder', 'test_files/bacterial_genome_1.txt', 'test_files/bacterial_genome_2.txt', '20', '50000000']
# for k=20 it took 23.994751930236816
# ['./KmerFinder', 'test_files/bacterial_genome_1.txt', 'test_files/bacterial_genome_2.txt', '30', '50000000']
# for k=30 it took 25.388322114944458
# ['./KmerFinder', 'test_files/bacterial_genome_1.txt', 'test_files/bacterial_genome_2.txt', '40', '50000000']
# for k=40 it took 26.877753973007202
# ['./KmerFinder', 'test_files/bacterial_genome_1.txt', 'test_files/bacterial_genome_2.txt', '50', '50000000']
# for k=50 it took 28.497862100601196
# ['./KmerFinder', 'test_files/bacterial_genome_1.txt', 'test_files/bacterial_genome_2.txt', '60', '50000000']
# for k=60 it took 29.921590089797974
# ['./KmerFinder', 'test_files/bacterial_genome_1.txt', 'test_files/bacterial_genome_2.txt', '70', '50000000']
# for k=70 it took 31.620625257492065
# ['./KmerFinder', 'test_files/bacterial_genome_1.txt', 'test_files/bacterial_genome_2.txt', '80', '50000000']
# for k=80 it took 33.03316402435303
# ['./KmerFinder', 'test_files/bacterial_genome_1.txt', 'test_files/bacterial_genome_2.txt', '90', '50000000']
# for k=90 it took 34.5680718421936
# ['./KmerFinder', 'test_files/bacterial_genome_1.txt', 'test_files/bacterial_genome_2.txt', '100', '50000000']
# for k=100 it took 36.269888162612915
# ['./KmerFinder', 'test_files/bacterial_genome_1.txt', 'test_files/bacterial_genome_2.txt', '110', '50000000']
# for k=110 it took 38.34240508079529
# ['./KmerFinder', 'test_files/bacterial_genome_1.txt', 'test_files/bacterial_genome_2.txt', '120', '50000000']
# for k=120 it took 39.41718006134033
# ['./KmerFinder', 'test_files/bacterial_genome_1.txt', 'test_files/bacterial_genome_2.txt', '130', '50000000']
# for k=130 it took 40.940922021865845
# ['./KmerFinder', 'test_files/bacterial_genome_1.txt', 'test_files/bacterial_genome_2.txt', '140', '50000000']
# for k=140 it took 42.68724608421326
# ['./KmerFinder', 'test_files/bacterial_genome_1.txt', 'test_files/bacterial_genome_2.txt', '150', '50000000']
# for k=150 it took 44.11801195144653
# ['./KmerFinder', 'test_files/bacterial_genome_1.txt', 'test_files/bacterial_genome_2.txt', '160', '50000000']
# for k=160 it took 45.62070679664612
# ['./KmerFinder', 'test_files/bacterial_genome_1.txt', 'test_files/bacterial_genome_2.txt', '170', '50000000']
# for k=170 it took 47.139853715896606
# ['./KmerFinder', 'test_files/bacterial_genome_1.txt', 'test_files/bacterial_genome_2.txt', '180', '50000000']
# for k=180 it took 48.6696720123291
# ['./KmerFinder', 'test_files/bacterial_genome_1.txt', 'test_files/bacterial_genome_2.txt', '190', '50000000']
# for k=190 it took 50.31123995780945
# ['./KmerFinder', 'test_files/bacterial_genome_1.txt', 'test_files/bacterial_genome_2.txt', '200', '50000000']
# for k=200 it took 51.558830976486206
# ['./KmerFinder', 'test_files/bacterial_genome_1.txt', 'test_files/bacterial_genome_2.txt', '210', '50000000']
# for k=210 it took 53.38337516784668
# ['./KmerFinder', 'test_files/bacterial_genome_1.txt', 'test_files/bacterial_genome_2.txt', '220', '50000000']
# for k=220 it took 54.508190870285034
# ['./KmerFinder', 'test_files/bacterial_genome_1.txt', 'test_files/bacterial_genome_2.txt', '230', '50000000']
# for k=230 it took 56.59993815422058
# ['./KmerFinder', 'test_files/bacterial_genome_1.txt', 'test_files/bacterial_genome_2.txt', '240', '50000000']
# for k=240 it took 58.041837215423584
# ['./KmerFinder', 'test_files/bacterial_genome_1.txt', 'test_files/bacterial_genome_2.txt', '250', '50000000']
# for k=250 it took 59.54761791229248
# ['./KmerFinder', 'test_files/bacterial_genome_1.txt', 'test_files/bacterial_genome_2.txt', '260', '50000000']
# for k=260 it took 61.06669068336487
# ['./KmerFinder', 'test_files/bacterial_genome_1.txt', 'test_files/bacterial_genome_2.txt', '270', '50000000']
# for k=270 it took 62.54387712478638
# ['./KmerFinder', 'test_files/bacterial_genome_1.txt', 'test_files/bacterial_genome_2.txt', '280', '50000000']
# for k=280 it took 64.23548102378845
# ['./KmerFinder', 'test_files/bacterial_genome_1.txt', 'test_files/bacterial_genome_2.txt', '290', '50000000']
# for k=290 it took 65.76399087905884
# ['./KmerFinder', 'test_files/bacterial_genome_1.txt', 'test_files/bacterial_genome_2.txt', '300', '50000000']
# for k=300 it took 67.16333198547363
# ['./KmerFinder', 'test_files/bacterial_genome_1.txt', 'test_files/bacterial_genome_2.txt', '310', '50000000']
# for k=310 it took 69.15005803108215
# ['./KmerFinder', 'test_files/bacterial_genome_1.txt', 'test_files/bacterial_genome_2.txt', '320', '50000000']
# for k=320 it took 70.00046420097351
# ['./KmerFinder', 'test_files/bacterial_genome_1.txt', 'test_files/bacterial_genome_2.txt', '330', '50000000']
# for k=330 it took 72.0958960056305
# ['./KmerFinder', 'test_files/bacterial_genome_1.txt', 'test_files/bacterial_genome_2.txt', '340', '50000000']
# for k=340 it took 73.34027099609375
# ['./KmerFinder', 'test_files/bacterial_genome_1.txt', 'test_files/bacterial_genome_2.txt', '350', '50000000']
# for k=350 it took 74.31474995613098
# ['./KmerFinder', 'test_files/bacterial_genome_1.txt', 'test_files/bacterial_genome_2.txt', '360', '50000000']
# for k=360 it took 76.2042281627655
# ['./KmerFinder', 'test_files/bacterial_genome_1.txt', 'test_files/bacterial_genome_2.txt', '370', '50000000']
# for k=370 it took 77.61657190322876
# ['./KmerFinder', 'test_files/bacterial_genome_1.txt', 'test_files/bacterial_genome_2.txt', '380', '50000000']
# for k=380 it took 79.7457799911499
# ['./KmerFinder', 'test_files/bacterial_genome_1.txt', 'test_files/bacterial_genome_2.txt', '390', '50000000']
# for k=390 it took 81.39519000053406
# ['./KmerFinder', 'test_files/bacterial_genome_1.txt', 'test_files/bacterial_genome_2.txt', '400', '50000000']
# for k=400 it took 82.15836596488953
# ['./KmerFinder', 'test_files/bacterial_genome_1.txt', 'test_files/bacterial_genome_2.txt', '410', '50000000']
# for k=410 it took 83.53850197792053
# ['./KmerFinder', 'test_files/bacterial_genome_1.txt', 'test_files/bacterial_genome_2.txt', '420', '50000000']
# for k=420 it took 85.10136866569519
# ['./KmerFinder', 'test_files/bacterial_genome_1.txt', 'test_files/bacterial_genome_2.txt', '430', '50000000']
# for k=430 it took 87.21453976631165
# ['./KmerFinder', 'test_files/bacterial_genome_1.txt', 'test_files/bacterial_genome_2.txt', '440', '50000000']
# for k=440 it took 88.08910012245178
# ['./KmerFinder', 'test_files/bacterial_genome_1.txt', 'test_files/bacterial_genome_2.txt', '450', '50000000']
# for k=450 it took 89.82080793380737
# ['./KmerFinder', 'test_files/bacterial_genome_1.txt', 'test_files/bacterial_genome_2.txt', '460', '50000000']
# for k=460 it took 91.17455315589905
# ['./KmerFinder', 'test_files/bacterial_genome_1.txt', 'test_files/bacterial_genome_2.txt', '470', '50000000']
# for k=470 it took 92.23903012275696
# ['./KmerFinder', 'test_files/bacterial_genome_1.txt', 'test_files/bacterial_genome_2.txt', '480', '50000000']
# for k=480 it took 94.20806813240051
# ['./KmerFinder', 'test_files/bacterial_genome_1.txt', 'test_files/bacterial_genome_2.txt', '490', '50000000']
# for k=490 it took 95.63431596755981

# %%
k_arr = []
time_arr = []
for k, t in benchmarking.items():
    if int(k.split(",")[0]) == 0:
        k_arr.append(int(k.split(",")[-1]))
        time_arr.append(round(t,2))
        
k_arr2 = []
time_arr2 = []
for k, t in benchmarking.items():
    if int(k.split(",")[0]) == 1:
        k_arr2.append(int(k.split(",")[-1]))
        time_arr2.append(round(t,2))

# %%
plt.figure(figsize=(10, 5), dpi=80)
plt.plot(k_arr, time_arr, label="without rolling")
plt.plot(k_arr2, time_arr2, label="with rolling")
plt.title("Benchmarking Rolling vs non-rolling Hash Functions \n'")
plt.xlabel("kmer/pattern Size")
plt.ylabel("Time (seconds)")
plt.legend()

# %% [markdown]
# ## testing impact of hash table size

# %%
file_1 = "test_files/bacterial_genome_1.txt"
file_2 = "test_files/bacterial_genome_2.txt"
hashtable_size = 50000000
kmer_size=20
benchmarking2 = {}
for hashtable_size in range(100000,1000000,100000):
    start = time.time()
    run_kmerfinder(file_1, file_2, kmer_size, hashtable_size, 1)
    time_to_run = time.time() - start
    benchmarking2[f"{use_rolling},{hashtable_size},{kmer_size}"] = time_to_run
    print(f"for k={hashtable_size} it took {time_to_run}")
# Out:
# ['./KmerFinder', 'test_files/bacterial_genome_1.txt', 'test_files/bacterial_genome_2.txt', '20', '100000', '--use_rolling']
# for k=100000 it took 389.3505620956421
# ['./KmerFinder', 'test_files/bacterial_genome_1.txt', 'test_files/bacterial_genome_2.txt', '20', '200000', '--use_rolling']
# for k=200000 it took 392.0307641029358
# ['./KmerFinder', 'test_files/bacterial_genome_1.txt', 'test_files/bacterial_genome_2.txt', '20', '300000', '--use_rolling']
# for k=300000 it took 140.18310403823853
# ['./KmerFinder', 'test_files/bacterial_genome_1.txt', 'test_files/bacterial_genome_2.txt', '20', '400000', '--use_rolling']
# for k=400000 it took 394.77237033843994
# ['./KmerFinder', 'test_files/bacterial_genome_1.txt', 'test_files/bacterial_genome_2.txt', '20', '500000', '--use_rolling']
# for k=500000 it took 115.85815715789795
# ['./KmerFinder', 'test_files/bacterial_genome_1.txt', 'test_files/bacterial_genome_2.txt', '20', '600000', '--use_rolling']
# for k=600000 it took 137.79170203208923
# ['./KmerFinder', 'test_files/bacterial_genome_1.txt', 'test_files/bacterial_genome_2.txt', '20', '700000', '--use_rolling']
# for k=700000 it took 65.43038988113403
# ['./KmerFinder', 'test_files/bacterial_genome_1.txt', 'test_files/bacterial_genome_2.txt', '20', '800000', '--use_rolling']
# for k=800000 it took 393.5518870353699
# ['./KmerFinder', 'test_files/bacterial_genome_1.txt', 'test_files/bacterial_genome_2.txt', '20', '900000', '--use_rolling']
# for k=900000 it took 52.12074279785156

# %%
for hashtable_size in range(1000000,2000000,100000):
    start = time.time()
    run_kmerfinder(file_1, file_2, kmer_size, hashtable_size, 1)
    time_to_run = time.time() - start
    benchmarking2[f"{use_rolling},{hashtable_size},{kmer_size}"] = time_to_run
    print(f"for k={hashtable_size} it took {time_to_run}")
# Out:
# ['./KmerFinder', 'test_files/bacterial_genome_1.txt', 'test_files/bacterial_genome_2.txt', '20', '1000000', '--use_rolling']
# for k=1000000 it took 114.62918090820312
# ['./KmerFinder', 'test_files/bacterial_genome_1.txt', 'test_files/bacterial_genome_2.txt', '20', '1100000', '--use_rolling']
# for k=1100000 it took 43.32831788063049
# ['./KmerFinder', 'test_files/bacterial_genome_1.txt', 'test_files/bacterial_genome_2.txt', '20', '1200000', '--use_rolling']
# for k=1200000 it took 150.05292391777039
# ['./KmerFinder', 'test_files/bacterial_genome_1.txt', 'test_files/bacterial_genome_2.txt', '20', '1300000', '--use_rolling']
# for k=1300000 it took 38.255587100982666
# ['./KmerFinder', 'test_files/bacterial_genome_1.txt', 'test_files/bacterial_genome_2.txt', '20', '1400000', '--use_rolling']
# for k=1400000 it took 64.96999382972717
# ['./KmerFinder', 'test_files/bacterial_genome_1.txt', 'test_files/bacterial_genome_2.txt', '20', '1500000', '--use_rolling']
# for k=1500000 it took 42.41968107223511
# ['./KmerFinder', 'test_files/bacterial_genome_1.txt', 'test_files/bacterial_genome_2.txt', '20', '1600000', '--use_rolling']
# for k=1600000 it took 392.46512722969055
# ['./KmerFinder', 'test_files/bacterial_genome_1.txt', 'test_files/bacterial_genome_2.txt', '20', '1700000', '--use_rolling']
# for k=1700000 it took 0.7026257514953613
# ['./KmerFinder', 'test_files/bacterial_genome_1.txt', 'test_files/bacterial_genome_2.txt', '20', '1800000', '--use_rolling']
# for k=1800000 it took 54.12457895278931
# ['./KmerFinder', 'test_files/bacterial_genome_1.txt', 'test_files/bacterial_genome_2.txt', '20', '1900000', '--use_rolling']
# for k=1900000 it took 0.7375297546386719

# %%
# get load factor and time
loadfactor_arr = []
time_arr = []
input_count = len(open(file_1).readlines())
for k, t in benchmarking2.items():
    loadfactor_arr.append(int(k.split(",")[1]))
    time_arr.append(round(t,2))

# %%
# plotting
plt.figure(figsize=(10, 5), dpi=80)
plt.plot(loadfactor_arr, time_arr, label="without rolling")
plt.plot(loadfactor_arr, time_arr, label="with rolling")
plt.title("Impact of Load Factor on Substring Finding \n'")
plt.xlabel("Table Size")
plt.ylabel("Time (seconds)")
plt.legend()
